# %% [markdown]
# # Task 1: Sparks Foundation - Data Science
# ## Prediction Using Supervised ML
# ### Author: BOUCHRA BENGHAZALA

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import metrics

# %%
#Loading the dataset from https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv
data= pd.read_csv('https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#Dividing the data into "attributes" (inputs) and "labels" (outputs).
X=data.iloc[:,range(0,1)].values
y=data[['Scores']].values

# %%
# Plotting the distribution of scores
data.plot(x='Hours',y='Scores',style='o')
plt.title('Hours & Scors')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
#Spliting the data into training and testing
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=0)

# %%
#Training the linear regression model
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Plotting the regression line
line=model.coef_*X+model.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %%
#Making predictions
y_pred=model.predict(X_test)
y_pred
# Out:
# array([[16.88414476],
#        [33.73226078],
#        [75.357018  ],
#        [26.79480124],
#        [60.49103328]])

# %%
#Accuracy of the model
model.score(X_test,y_test)
# Out:
# 0.9454906892105355

# %%
#Predicting the student's score for 9.25hr/day
hours = 9.5
own_pred = model.predict([[hours]])
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.5
# Predicted Score = [96.16939661]

# %%
#Evaluating the model
MeanAbsoluteError=metrics.mean_absolute_error(y_test, y_pred)
print(MeanAbsoluteError)
# Out:
# 4.183859899002975
